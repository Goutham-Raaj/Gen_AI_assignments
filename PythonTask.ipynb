# %% [markdown]
# **Write a program to compare three numbers and tell which one is larger and smallest**

# %%
a=int(input("Enter number 1:"))
b=int(input("Enter number 2:"))
c=int(input("Enter number 3:"))
if a>b and a>c:
    print("The largest number is:a", a)
elif b>a and b>c:
    print("The largest number is:b", b)
else:
    print("The largest number is:c", c)
# Out:
# The largest number is:b 200
