# %% [markdown]
# **1.Create a variable x with value 10 and a variable y with value 20 and print their sum**

# %%
x=10
y=20
sum=x+y
print("Sum of x and y:",sum)
# Out:
# Sum of x and y: 30

# %% [markdown]
# **2.Assign your name to a variable and print "Hello, <"name">"**

# %%
name= "Goutham"
print("Hello,",name)
# Out:
# Hello, Goutham

# %% [markdown]
# 3. **Swap two variables a=5 and b=10 without using a third variable**

# %%
a=5
b=10
print("Before Swap a:",a)
print("Before Swap b:",b)
b=b-a
a=a+b
print("After Swap a:",a)
print("Aefore Swap b:",b)
# Out:
# Before Swap a: 5
# Before Swap b: 10
# After Swap a: 10
# Aefore Swap b: 5

# %% [markdown]
# **4.Take user input for age and print "You are <"age"> years old"**

# %%
age=input("Enter your age:")
print("You are",age,"years old.")
# Out:
# You are 18 years old.

# %% [markdown]
# **5.Write a python program to check whether a number is odd or even using modulus operator**

# %%
num1=int(input("Enter a number:"))
if(num1%2==0):
    print(num1,"is an even number.")
else:
    print(num1,"is an odd number.")
# Out:
# 2340 is an even number.

# %% [markdown]
# **6. if a=15 and b=4, find the sum, difference , product, division, modulus**

# %%
a1=15
b2=4
print("sum:",a1+b2)
print("difference:",a1-b2)
print("product:",a1*b2)
print("division:",a1/b2)
print("modulus:",a1%b2)
# Out:
# sum: 19
# difference: 11
# product: 60
# division: 3.75
# modulus: 3

# %% [markdown]
# **7.Write a python program which checks if a number is positive, negative or zero**

# %%
num2=int(input("Enter a number:"))
if(num2>0):
    print(num2,"is a positive number.")
elif(num2<0):
    print(num2,"is a negative number.")
else:
    print(num2,"is zero.")
# Out:
# 46 is a positive number.
